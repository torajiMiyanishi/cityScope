# %%
import json
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import json
# ----> 2 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
PATH_TO_MESH_SHP = "../../data/mesh/mesh_geom.shp"

# %%
epsg = 2451
mesh_geojson = gpd.read_file(PATH_TO_MESH_SHP).to_crs(epsg=epsg).to_json()

# %%
with open(f'../data/building_geojson_{epsg}.json', 'w') as file:
    file.write(mesh_geojson)

# %%
gpd.read_file(PATH_TO_MESH_SHP).to_crs(epsg=epsg).plot()
# Out:
# <Axes: >
